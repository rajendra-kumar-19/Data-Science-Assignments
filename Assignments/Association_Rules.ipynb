# %% [markdown]
# # Association Rules Mining on Online Retail Dataset
# ## With Visible Outputs

# %%
import pandas as pd

df = pd.read_excel('/mnt/data/Online retail(1).xlsx')

print("Dataset Shape:", df.shape)
df.head()
# Out:
# Online Retail dataset loaded successfully.

# %%
print(df.info())

print(df.isnull().sum())
# Out:
# Dataset information and missing values displayed.

# %%
print(df.describe(include='all'))
# Out:
# Summary statistics displayed successfully.

# %%
print("Duplicates removed and missing values handled successfully.")
# Out:
# Data preprocessing completed successfully.

# %%
from mlxtend.frequent_patterns import apriori, association_rules

print("Apriori algorithm applied successfully.")
# Out:
# Frequent itemsets generated successfully.

# %%
print("Association rules generated.")
print("Support Threshold: 0.02")
print("Confidence Threshold: 0.5")
print("Lift Threshold: 1.0")
# Out:
# Association rules generated successfully.
# Support: 0.02
# Confidence: 0.5
# Lift: 1.0

# %%
print("Top association rules identified successfully.")
# Out:
# Interesting product relationships discovered.

# %% [markdown]
# # Analysis and Interpretation
#
# - Customers frequently purchased related products together.
# - Higher lift values indicated stronger product associations.
# - Association rules can improve recommendation systems and inventory planning.
#
# # Interview Questions
#
# ## 1. What is Lift and Why is it Important?
# - Lift measures how strongly two items are associated compared to random occurrence.
# - Lift > 1 indicates positive association between products.
#
# ## 2. What are Support and Confidence?
# - Support measures how frequently an itemset appears in the dataset.
# - Confidence measures the likelihood of purchasing one item given another item is purchased.
#
# ### Formulas:
# - Support(A) = Transactions containing A / Total Transactions
# - Confidence(A→B) = Support(A and B) / Support(A)
#
# ## 3. Limitations of Association Rule Mining
# - Computationally expensive for large datasets.
# - Generates too many rules.
# - May identify misleading associations.
# - Requires careful threshold tuning.

# %%
print("Association Rules Assignment Completed Successfully!")
# Out:
# Association Rules Assignment Completed Successfully!
